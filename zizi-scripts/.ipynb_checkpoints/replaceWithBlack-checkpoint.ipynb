# %%
# !cp -r ../zizi-data/results/bolly-close ../zizi-data/results/bolly-close2
# Out:
# ^C

# %%
# !rm -rf ../zizi-data/results/bolly-close2/0*

# %%
import os
import glob
import numpy as np
import cv2

emptyFig = np.zeros((832,832,3), np.uint8)

outs=[]

for out in sorted(glob.glob("../zizi-data/results/*-close2")):
    outs.append(out)
    
print(outs)

for directory in sorted(glob.glob("../zizi-data/datasets/acts/close/test_densepose/*")):
    print(directory)
    for file in sorted(glob.glob(directory+"/*")):
        f = os.path.basename(os.path.splitext(file)[0])[:6]
        b = os.path.getsize(file)
        c = os.path.getsize("../zizi-data/datasets/acts/close/test_openpose/"+os.path.basename(directory)+"/"+f+"_keypoints.json")
        if b == 16887 and c == 27:
            print("both exist "+directory+f)
            
            for out in outs:
                cv2.imwrite(out+"/"+os.path.basename(directory)+"/"+f+".png", emptyFig)
# Out:
# ['../zizi-data/results/bolly-close2']
# ../zizi-data/datasets/acts/close/test_densepose/fiveyears-ruby-close
# both exist ../zizi-data/datasets/acts/close/test_densepose/fiveyears-ruby-close000001
# both exist ../zizi-data/datasets/acts/close/test_densepose/fiveyears-ruby-close000002
# both exist ../zizi-data/datasets/acts/close/test_densepose/fiveyears-ruby-close000003
# both exist ../zizi-data/datasets/acts/close/test_densepose/fiveyears-ruby-close000004
# both exist ../zizi-data/datasets/acts/close/test_densepose/fiveyears-ruby-close000005
# both exist ../zizi-data/datasets/acts/close/test_densepose/fiveyears-ruby-close000006
# both exist ../zizi-data/datasets/acts/close/test_densepose/fiveyears-ruby-close000007
# both exist ../zizi-data/datasets/acts/close/test_densepose/fiveyears-ruby-close000008
# both exist ../zizi-data/datasets/acts/close/test_densepose/fiveyears-ruby-close000009
# both exist ../zizi-data/datasets/acts/close/test_densepose/fiveyears-ruby-close000010
# ...

# %%
import os
import glob
import numpy as np
import cv2


                cv2.imwrite(out+"/"+os.path.basename(directory)+"/"+f+".png", emptyFig)


    

emptyFig = np.zeros((832,832,3), np.uint8)

outs=[]

foundFirst = False
Last = True
first=1000

for out in sorted(glob.glob("../zizi-data/results/*-close2")):
    outs.append(out)
    
print(outs)

def makeFade(number, direction, directory):
    print("fade"+str(number)+direction)
    im = cv2.imread('../zizi-data/datasets/acts/close/test_img/fiveyears-ruby-close/005001_IUV.png')
#     cv2.imwrite(out+"/"+os.path.basename(directory)+"/"+f+".png", emptyFig)

        
        

for directory in sorted(glob.glob("../zizi-data/datasets/acts/close/test_densepose/*")):
    print(directory)
    for file in sorted(glob.glob(directory+"/*")):
        f = os.path.basename(os.path.splitext(file)[0])[:6]
        b = os.path.getsize(file)
        c = os.path.getsize("../zizi-data/datasets/acts/close/test_openpose/"+os.path.basename(directory)+"/"+f+"_keypoints.json")
        
        if b != 16887 or c != 27:
            if foundFirst==False:
                print("first "+directory+" "+f)
                first = int(f)
                print(f)
                foundFirst = True
                makeFade(f, "forward", directory)
        
        if b == 16887 and c == 27 and int(f) > first:
            if foundLast==False:
                print("last "+directory+" "+f)
                last = int(f)
                print(f)
                foundLast = True
                makeFade(f, "backward", directory)

                

    foundFirst = False
    foundLast = False
    

    
    


            
#             for out in outs:
#                 cv2.imwrite(out+"/"+os.path.basename(directory)+"/"+f+".png", emptyFig)
# Out:
# ['../zizi-data/results/bolly-close2']
# ../zizi-data/datasets/acts/close/test_densepose/fiveyears-ruby-close
# first ../zizi-data/datasets/acts/close/test_densepose/fiveyears-ruby-close 000273
# 000273
# fade273forward
# last ../zizi-data/datasets/acts/close/test_densepose/fiveyears-ruby-close 006842
# 006842
# fade6842backward
# ../zizi-data/datasets/acts/close/test_densepose/freedom-mark-close
# first ../zizi-data/datasets/acts/close/test_densepose/freedom-mark-close 000262
# 000262
# fade262forward
# last ../zizi-data/datasets/acts/close/test_densepose/freedom-mark-close 006758
# 006758
# fade6758backward
# ../zizi-data/datasets/acts/close/test_densepose/glass-lilly-close
# first ../zizi-data/datasets/acts/close/test_densepose/glass-lilly-close 000058
# 000058
# fade58forward
# last ../zizi-data/datasets/acts/close/test_densepose/glass-lilly-close 005035
# 005035
# fade5035backward
# ../zizi-data/datasets/acts/close/test_densepose/iam-me-close
# ...

# %%
ls ../zizi-data/results/
# Out:
# amalgam-full/  bolly-close2/  lilly-close/  mahatma-full/
# bolly-close/   bolly-full/    lilly-full/

# %%
from PIL import Image, ImageOps, ImageFilter, ImageEnhance, ImageChops


number = 273
direction = "forward"
directory = "../zizi-data/datasets/acts/close/test_densepose/fiveyears-ruby-close"
out = "lilly-close"



num = number + 50


im = cv2.imread('../zizi-data/results/'+out+'/'+os.path.basename(directory)+'/'+str(num).zfill(6)+'.png')

im = im/255.0
im_power_law_transformation = cv2.pow(im,0.8)
im_PIL = Image.fromarray((im_power_law_transformation * 255).astype(np.uint8), mode='RGB')
blur1 = im_PIL.filter(ImageFilter.GaussianBlur(radius=51))

# im = Image.open('../zizi-data/results/'+out+'/'+os.path.basename(directory)+'/'+str(num).zfill(6)+'.png')

display(im_PIL)


#     cv2.imwrite(out+"/"+os.path.basename(directory)+"/"+f+".png", emptyFig)
# Out:
# <PIL.Image.Image image mode=RGB size=832x832 at 0x7F21653CE9B0>
